# %%
import numpy as np
import pandas as pd
import os
import nibabel as nib
import matplotlib.pyplot as plt

cta_volume = nib.load('C:\\Users\\20203226\\Documents\\CTA data\\1-200\\1.label.nii.gz').get_fdata()
print(cta_volume.shape)
# Out:
# C:\Users\20203226\Anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# (512, 512, 275)

# %%
from ipywidgets import interact, widgets

def cta_animation(x):
    plt.imshow(cta_volume[:,:,x], cmap='gray')
    return x

interact(cta_animation, x=(0, cta_volume.shape[2]-1))
# Out:
# interactive(children=(IntSlider(value=137, description='x', max=274), Output()), _dom_classes=('widget-interac…
# <function __main__.cta_animation(x)>

# %%
plt.imshow(cta_volume[:,:,34], cmap='gray')

# %%
import pyvista as pv

data = pv.wrap(cta_volume)
data.plot(volume=True) # Volume render
# Out:
# C:\Users\20203226\Anaconda3\envs\tf\lib\site-packages\pyvista\jupyter\notebook.py:34: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (C:\Users\20203226\Anaconda3\envs\tf\lib\site-packages\trame\widgets\__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
